# %%
import pandas as pd
import os

# %%
pwd = os.getcwd()

# %%
dataset = pd.read_excel(pwd + "/Data Survey - edited.xlsx")
dataset
# Out:
#      Respondent ID          Start Date            End Date  Email Address  \
# 0              NaN                 NaT                 NaT            NaN
# 1     5.379192e+09 2021-01-22 12:01:17 2021-01-22 12:40:34            NaN
# 2     2.658723e+09 2021-01-22 06:56:37 2021-01-22 07:34:10            NaN
# 3     4.044163e+09 2021-01-22 06:35:18 2021-01-22 06:47:32            NaN
# 4     5.535866e+09 2021-01-21 21:29:32 2021-01-21 21:40:24            NaN
# ..             ...                 ...                 ...            ...
# 194   7.940065e+09 2021-01-11 06:19:18 2021-01-11 06:32:59            NaN
# 195   5.157706e+09 2021-01-11 06:19:14 2021-01-11 06:33:29            NaN
# 196   9.920756e+09 2021-01-11 06:18:48 2021-01-11 06:27:27            NaN
# 197   6.638341e+09 2021-01-11 06:19:01 2021-01-11 06:33:06            NaN
# 198   8.114622e+09 2021-01-11 06:18:50 2021-01-11 06:26:46            NaN
#
#      First Name  Last Name  Custom Data 1  \
# 0           NaN        NaN            NaN
# 1           NaN        NaN            NaN
# 2           NaN        NaN            NaN
# 3           NaN        NaN            NaN
# 4           NaN        NaN            NaN
# ..          ...        ...            ...
# 194         NaN        NaN            NaN
# 195         NaN        NaN            NaN
# 196         NaN        NaN            NaN
# 197         NaN        NaN            NaN
# 198         NaN        NaN            NaN
#
#     Identify which division you work in.              Unnamed: 8  \
# 0                               Response  Other (please specify)
# 1                         Infrastructure                     NaN
# 2                                Finance                     NaN
# 3                         Infrastructure                     NaN
# 4                         Infrastructure                     NaN
# ..                                   ...                     ...
# 194                       Infrastructure                     NaN
# 195                              Finance                     NaN
# 196                      Port Operations                     NaN
# 197                       Infrastructure                     NaN
# 198               Information Technology                     NaN
#
#     Which of the following best describes your position level?  ...  \
# 0                                             Response          ...
# 1                                                Staff          ...
# 2                                                Staff          ...
# 3                                      Department Lead          ...
# 4                                              Manager          ...
# ..                                                 ...          ...
# 194                                    Department Lead          ...
# 195                                              Staff          ...
# 196                                              Staff          ...
# 197                                            Manager          ...
# 198                                              Staff          ...
#
#     Unnamed: 90 Unnamed: 91  Unnamed: 92  Unnamed: 93  Unnamed: 94  \
# 0    Response 8  Response 9  Response 10  Response 11  Response 12
# 1           NaN    Answer 8     Answer 8     Answer 4          NaN
# 2           NaN    Answer 5          NaN          NaN     Answer 2
# 3           NaN         NaN     Answer 4     Answer 4     Answer 6
# 4      Answer 2    Answer 5     Answer 7          NaN     Answer 6
# ..          ...         ...          ...          ...          ...
# 194    Answer 1    Answer 1     Answer 3     Answer 6     Answer 6
# 195    Answer 5         NaN     Answer 5          NaN          NaN
# 196         NaN    Answer 7          NaN          NaN          NaN
# 197    Answer 2         NaN     Answer 3     Answer 5          NaN
# 198    Answer 3         NaN     Answer 7          NaN          NaN
#
#      Unnamed: 95  Unnamed: 96 Question 30 Unnamed: 98 Unnamed: 99
# 0    Response 13  Response 14  Response 1  Response 2  Response 3
# 1            NaN     Answer 5         NaN         NaN         NaN
# 2            NaN     Answer 5         NaN         NaN    Answer 1
# 3            NaN     Answer 6         NaN    Answer 1         NaN
# 4            NaN     Answer 7    Answer 7    Answer 1    Answer 6
# ..           ...          ...         ...         ...         ...
# 194     Answer 8          NaN         NaN         NaN    Answer 8
# 195     Answer 2          NaN         NaN         NaN    Answer 6
# 196          NaN          NaN         NaN    Answer 3         NaN
# 197     Answer 8     Answer 3    Answer 3         NaN         NaN
# 198          NaN          NaN    Answer 3         NaN         NaN
#
# [199 rows x 100 columns]

# %%
dataset_modified = dataset.copy()
dataset_modified
# Out:
#      Respondent ID          Start Date            End Date  Email Address  \
# 0              NaN                 NaT                 NaT            NaN
# 1     5.379192e+09 2021-01-22 12:01:17 2021-01-22 12:40:34            NaN
# 2     2.658723e+09 2021-01-22 06:56:37 2021-01-22 07:34:10            NaN
# 3     4.044163e+09 2021-01-22 06:35:18 2021-01-22 06:47:32            NaN
# 4     5.535866e+09 2021-01-21 21:29:32 2021-01-21 21:40:24            NaN
# ..             ...                 ...                 ...            ...
# 194   7.940065e+09 2021-01-11 06:19:18 2021-01-11 06:32:59            NaN
# 195   5.157706e+09 2021-01-11 06:19:14 2021-01-11 06:33:29            NaN
# 196   9.920756e+09 2021-01-11 06:18:48 2021-01-11 06:27:27            NaN
# 197   6.638341e+09 2021-01-11 06:19:01 2021-01-11 06:33:06            NaN
# 198   8.114622e+09 2021-01-11 06:18:50 2021-01-11 06:26:46            NaN
#
#      First Name  Last Name  Custom Data 1  \
# 0           NaN        NaN            NaN
# 1           NaN        NaN            NaN
# 2           NaN        NaN            NaN
# 3           NaN        NaN            NaN
# 4           NaN        NaN            NaN
# ..          ...        ...            ...
# 194         NaN        NaN            NaN
# 195         NaN        NaN            NaN
# 196         NaN        NaN            NaN
# 197         NaN        NaN            NaN
# 198         NaN        NaN            NaN
#
#     Identify which division you work in.              Unnamed: 8  \
# 0                               Response  Other (please specify)
# 1                         Infrastructure                     NaN
# 2                                Finance                     NaN
# 3                         Infrastructure                     NaN
# 4                         Infrastructure                     NaN
# ..                                   ...                     ...
# 194                       Infrastructure                     NaN
# 195                              Finance                     NaN
# 196                      Port Operations                     NaN
# 197                       Infrastructure                     NaN
# 198               Information Technology                     NaN
#
#     Which of the following best describes your position level?  ...  \
# 0                                             Response          ...
# 1                                                Staff          ...
# 2                                                Staff          ...
# 3                                      Department Lead          ...
# 4                                              Manager          ...
# ..                                                 ...          ...
# 194                                    Department Lead          ...
# 195                                              Staff          ...
# 196                                              Staff          ...
# 197                                            Manager          ...
# 198                                              Staff          ...
#
#     Unnamed: 90 Unnamed: 91  Unnamed: 92  Unnamed: 93  Unnamed: 94  \
# 0    Response 8  Response 9  Response 10  Response 11  Response 12
# 1           NaN    Answer 8     Answer 8     Answer 4          NaN
# 2           NaN    Answer 5          NaN          NaN     Answer 2
# 3           NaN         NaN     Answer 4     Answer 4     Answer 6
# 4      Answer 2    Answer 5     Answer 7          NaN     Answer 6
# ..          ...         ...          ...          ...          ...
# 194    Answer 1    Answer 1     Answer 3     Answer 6     Answer 6
# 195    Answer 5         NaN     Answer 5          NaN          NaN
# 196         NaN    Answer 7          NaN          NaN          NaN
# 197    Answer 2         NaN     Answer 3     Answer 5          NaN
# 198    Answer 3         NaN     Answer 7          NaN          NaN
#
#      Unnamed: 95  Unnamed: 96 Question 30 Unnamed: 98 Unnamed: 99
# 0    Response 13  Response 14  Response 1  Response 2  Response 3
# 1            NaN     Answer 5         NaN         NaN         NaN
# 2            NaN     Answer 5         NaN         NaN    Answer 1
# 3            NaN     Answer 6         NaN    Answer 1         NaN
# 4            NaN     Answer 7    Answer 7    Answer 1    Answer 6
# ..           ...          ...         ...         ...         ...
# 194     Answer 8          NaN         NaN         NaN    Answer 8
# 195     Answer 2          NaN         NaN         NaN    Answer 6
# 196          NaN          NaN         NaN    Answer 3         NaN
# 197     Answer 8     Answer 3    Answer 3         NaN         NaN
# 198          NaN          NaN    Answer 3         NaN         NaN
#
# [199 rows x 100 columns]

# %%
columns_to_drop = ['Start Date - ', 'End Date - ', 'Email Address - ','First Name - ', 'Last Name - ', 'Custom Data 1 - ',]
columns_to_drop
# Out:
# ['Start Date - ',
#  'End Date - ',
#  'Email Address - ',
#  'First Name - ',
#  'Last Name - ',
#  'Custom Data 1 - ']

# %%
dataset_modified = dataset_modified.drop(columns=columns_to_drop)
dataset_modified
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 dataset_modified = dataset_modified.drop(columns=columns_to_drop)
#       2 dataset_modified
#
# File c:\Users\franc\anaconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# File c:\Users\franc\anaconda3\Lib\site-packages\pandas\core\generic.py:4788, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786 for axis, labels in axes.items():
#    4787     if labels is not None:
# -> 4788         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4790 if inplace:
#    4791     self._update_inplace(obj)
#
# File c:\Users\franc\anaconda3\Lib\site-packages\pandas\core\generic.py:4830, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4828         new_axis = axis.drop(labels, level=level, errors=errors)
#    4829     else:
# -> 4830         new_axis = axis.drop(labels, errors=errors)
#    4831     indexer = axis.get_indexer(new_axis)
#    4833 # Case for non-unique axis
#    4834 else:
#
# File c:\Users\franc\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: "['Start Date - ', 'End Date - ', 'Email Address - ', 'First Name - ', 'Last Name - ', 'Custom Data 1 - '] not found in axis"

# %%
id_vars = list(dataset_modified.columns)[ : 8] 
value_vars = list(dataset_modified.columns)[8 : ] 
# value_vars

# %%
dataset_melted = dataset_modified.melt(id_vars = id_vars, value_vars = value_vars, var_name="Question + Subquestion", value_name="Answer")
dataset_melted
# Out:
#        Respondent ID -  Identify which division you work in. - Response  \
# 0            5379192392                                  Infrastructure
# 1            2658722536                                         Finance
# 2            4044163394                                  Infrastructure
# 3            5535865599                                  Infrastructure
# 4            3356802928                                 Port Operations
# ...                 ...                                             ...
# 17023        7940065082                                  Infrastructure
# 17024        5157705612                                         Finance
# 17025        9920755555                                 Port Operations
# 17026        6638341389                                  Infrastructure
# 17027        8114622230                          Information Technology
#
#       Identify which division you work in. - Other (please specify)  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 17023                                                NaN
# 17024                                                NaN
# 17025                                                NaN
# 17026                                                NaN
# 17027                                                NaN
#
#       Which of the following best describes your position level? - Response  \
# 0                                                  Staff
# 1                                                  Staff
# 2                                        Department Lead
# 3                                                Manager
# 4                                                Manager
# ...                                                  ...
# 17023                                    Department Lead
# 17024                                              Staff
# 17025                                              Staff
# 17026                                            Manager
# 17027                                              Staff
#
#       Which generation are you apart of? - Response  \
# 0             Generation X (born between 1965-1980)
# 1                                               NaN
# 2             Generation X (born between 1965-1980)
# 3               Millennial (born between 1981-2000)
# 4             Generation X (born between 1965-1980)
# ...                                             ...
# 17023          Baby Boomer (born between 1946-1964)
# 17024           Millennial (born between 1981-2000)
# 17025           Millennial (born between 1981-2000)
# 17026           Millennial (born between 1981-2000)
# 17027                          Prefer not to answer
#
#       Please select the gender in which you identify. - Response  \
# 0                                                   Male
# 1                                                    NaN
# 2                                                   Male
# 3                                             Non-Binary
# 4                                                 Female
# ...                                                  ...
# 17023                                               Male
# 17024                                             Female
# 17025                                             Female
# 17026                                             Female
# 17027                                               Male
#
#       Which duration range best aligns with your tenure at your company? - Response  \
# 0                                              0-2 years
# 1                                              10+ years
# 2                                              3-5 years
# 3                                             5-10 years
# 4                                              10+ years
# ...                                                  ...
# 17023                                          10+ years
# 17024                                         5-10 years
# 17025                                          3-5 years
# 17026                                          3-5 years
# 17027                                         5-10 years
#
#       Which of the following best describes your employment type? - Response  \
# 0                                     Full time Employee
# 1                                     Full time Employee
# 2                                     Full time Employee
# 3                                     Full time Employee
# 4                                     Full time Employee
# ...                                                  ...
# 17023                                 Full time Employee
# 17024                                 Full time Employee
# 17025                                 Full time Employee
# 17026                                 Full time Employee
# 17027                                 Full time Employee
#
#          Question + Subquestion    Answer
# 0         Question 1 - Response       NaN
# 1         Question 1 - Response  Answer 4
# 2         Question 1 - Response  Answer 5
# 3         Question 1 - Response  Answer 1
# 4         Question 1 - Response       NaN
# ...                         ...       ...
# 17023  Question 30 - Response 3  Answer 8
# 17024  Question 30 - Response 3  Answer 6
# 17025  Question 30 - Response 3       NaN
# 17026  Question 30 - Response 3       NaN
# 17027  Question 30 - Response 3       NaN
#
# [17028 rows x 10 columns]

# %%
questions_import =  pd.read_excel(pwd + "/Data Survey - edited.xlsx", sheet_name="Questions")
questions_import
# Out:
#          Question Raw Subquestion      Question   Subquestion  \
# 0   Respondent ID             NaN  Respondent ID          NaN
# 1      Start Date             NaN     Start Date          NaN
# 2        End Date             NaN       End Date          NaN
# 3   Email Address             NaN  Email Address          NaN
# 4      First Name             NaN     First Name          NaN
# ..            ...             ...            ...          ...
# 95            NaN     Response 13    Question 29  Response 13
# 96            NaN     Response 14    Question 29  Response 14
# 97    Question 30      Response 1    Question 30   Response 1
# 98            NaN      Response 2    Question 30   Response 2
# 99            NaN      Response 3    Question 30   Response 3
#
#       Question + Subquestions
# 0            Respondent ID -
# 1               Start Date -
# 2                 End Date -
# 3            Email Address -
# 4               First Name -
# ..                        ...
# 95  Question 29 - Response 13
# 96  Question 29 - Response 14
# 97   Question 30 - Response 1
# 98   Question 30 - Response 2
# 99   Question 30 - Response 3
#
# [100 rows x 5 columns]

# %%
questions = questions_import.copy()
questions.drop(columns=["Question", "Raw Subquestion", "Subquestion"], inplace=True)

# %%
questions
# Out:
#         Question     Question + Subquestions
# 0   Respondent ID           Respondent ID -
# 1      Start Date              Start Date -
# 2        End Date                End Date -
# 3   Email Address           Email Address -
# 4      First Name              First Name -
# ..            ...                        ...
# 95    Question 29  Question 29 - Response 13
# 96    Question 29  Question 29 - Response 14
# 97    Question 30   Question 30 - Response 1
# 98    Question 30   Question 30 - Response 2
# 99    Question 30   Question 30 - Response 3
#
# [100 rows x 2 columns]

# %%
questions.rename(columns={'Question + Subquestions': 'Question + Subquestion'}, inplace=True)

# %%
dataset_merged = pd.merge(left=dataset_melted, right=questions, how='left', on='Question + Subquestion')
print('Original Data:', len(dataset_melted))
print('Merged Data:', len(dataset_merged))

dataset_merged
# Out:
# Original Data: 17028
# Merged Data: 17028
#        Respondent ID -  Identify which division you work in. - Response  \
# 0            5379192392                                  Infrastructure
# 1            2658722536                                         Finance
# 2            4044163394                                  Infrastructure
# 3            5535865599                                  Infrastructure
# 4            3356802928                                 Port Operations
# ...                 ...                                             ...
# 17023        7940065082                                  Infrastructure
# 17024        5157705612                                         Finance
# 17025        9920755555                                 Port Operations
# 17026        6638341389                                  Infrastructure
# 17027        8114622230                          Information Technology
#
#       Identify which division you work in. - Other (please specify)  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 17023                                                NaN
# 17024                                                NaN
# 17025                                                NaN
# 17026                                                NaN
# 17027                                                NaN
#
#       Which of the following best describes your position level? - Response  \
# 0                                                  Staff
# 1                                                  Staff
# 2                                        Department Lead
# 3                                                Manager
# 4                                                Manager
# ...                                                  ...
# 17023                                    Department Lead
# 17024                                              Staff
# 17025                                              Staff
# 17026                                            Manager
# 17027                                              Staff
#
#       Which generation are you apart of? - Response  \
# 0             Generation X (born between 1965-1980)
# 1                                               NaN
# 2             Generation X (born between 1965-1980)
# 3               Millennial (born between 1981-2000)
# 4             Generation X (born between 1965-1980)
# ...                                             ...
# 17023          Baby Boomer (born between 1946-1964)
# 17024           Millennial (born between 1981-2000)
# 17025           Millennial (born between 1981-2000)
# 17026           Millennial (born between 1981-2000)
# 17027                          Prefer not to answer
#
#       Please select the gender in which you identify. - Response  \
# 0                                                   Male
# 1                                                    NaN
# 2                                                   Male
# 3                                             Non-Binary
# 4                                                 Female
# ...                                                  ...
# 17023                                               Male
# 17024                                             Female
# 17025                                             Female
# 17026                                             Female
# 17027                                               Male
#
#       Which duration range best aligns with your tenure at your company? - Response  \
# 0                                              0-2 years
# 1                                              10+ years
# 2                                              3-5 years
# 3                                             5-10 years
# 4                                              10+ years
# ...                                                  ...
# 17023                                          10+ years
# 17024                                         5-10 years
# 17025                                          3-5 years
# 17026                                          3-5 years
# 17027                                         5-10 years
#
#       Which of the following best describes your employment type? - Response  \
# 0                                     Full time Employee
# 1                                     Full time Employee
# 2                                     Full time Employee
# 3                                     Full time Employee
# 4                                     Full time Employee
# ...                                                  ...
# 17023                                 Full time Employee
# 17024                                 Full time Employee
# 17025                                 Full time Employee
# 17026                                 Full time Employee
# 17027                                 Full time Employee
#
#          Question + Subquestion    Answer    Question
# 0         Question 1 - Response       NaN   Question 1
# 1         Question 1 - Response  Answer 4   Question 1
# 2         Question 1 - Response  Answer 5   Question 1
# 3         Question 1 - Response  Answer 1   Question 1
# 4         Question 1 - Response       NaN   Question 1
# ...                         ...       ...          ...
# 17023  Question 30 - Response 3  Answer 8  Question 30
# 17024  Question 30 - Response 3  Answer 6  Question 30
# 17025  Question 30 - Response 3       NaN  Question 30
# 17026  Question 30 - Response 3       NaN  Question 30
# 17027  Question 30 - Response 3       NaN  Question 30
#
# [17028 rows x 11 columns]

# %%
print(dataset_merged.columns)
# Out:
# Index(['Respondent ID - ', 'Identify which division you work in. - Response',
#        'Identify which division you work in. - Other (please specify)',
#        'Which of the following best describes your position level? - Response',
#        'Which generation are you apart of? - Response',
#        'Please select the gender in which you identify. - Response',
#        'Which duration range best aligns with your tenure at your company? - Response',
#        'Which of the following best describes your employment type? - Response',
#        'Question + Subquestion', 'Answer', 'Question '],
#       dtype='object')

# %%
respondents = dataset_merged[dataset_merged["Answer"].notna()]
respondents = respondents.groupby("Question ")["Respondent ID - "].count().reset_index()
respondents.rename(columns={"Respondent ID":"Respondents"}, inplace=True)
respondents
# Out:
#       Question   Respondent ID -
# 0    Question 1               119
# 1   Question 10               585
# 2   Question 11               239
# 3   Question 12               114
# 4   Question 13               108
# 5   Question 14               105
# 6   Question 15               114
# 7   Question 16               117
# 8   Question 17               135
# 9   Question 18               109
# 10  Question 19               226
# 11   Question 2               118
# 12  Question 20               105
# 13  Question 21               127
# 14  Question 22               214
# 15  Question 23               120
# 16  Question 24               544
# 17  Question 25               970
# 18  Question 26               436
# 19  Question 27               211
# 20  Question 28               119
# 21  Question 29              1584
# 22   Question 3               117
# 23  Question 30               332
# 24   Question 4               220
# 25   Question 5               676
# 26   Question 6               664
# 27   Question 7               237
# 28   Question 8               446
# 29   Question 9               453

# %%
dataset_merged_two = pd.merge(left=dataset_merged, right=respondents, how='left', left_on='Question ', right_on='Question ')
print('Original Data:', len(dataset_merged))
print('Merged Data:', len(dataset_merged_two))

dataset_merged_two
# Out:
# Original Data: 17028
# Merged Data: 17028
#        Respondent ID - _x Identify which division you work in. - Response  \
# 0              5379192392                                  Infrastructure
# 1              2658722536                                         Finance
# 2              4044163394                                  Infrastructure
# 3              5535865599                                  Infrastructure
# 4              3356802928                                 Port Operations
# ...                   ...                                             ...
# 17023          7940065082                                  Infrastructure
# 17024          5157705612                                         Finance
# 17025          9920755555                                 Port Operations
# 17026          6638341389                                  Infrastructure
# 17027          8114622230                          Information Technology
#
#       Identify which division you work in. - Other (please specify)  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 17023                                                NaN
# 17024                                                NaN
# 17025                                                NaN
# 17026                                                NaN
# 17027                                                NaN
#
#       Which of the following best describes your position level? - Response  \
# 0                                                  Staff
# 1                                                  Staff
# 2                                        Department Lead
# 3                                                Manager
# 4                                                Manager
# ...                                                  ...
# 17023                                    Department Lead
# 17024                                              Staff
# 17025                                              Staff
# 17026                                            Manager
# 17027                                              Staff
#
#       Which generation are you apart of? - Response  \
# 0             Generation X (born between 1965-1980)
# 1                                               NaN
# 2             Generation X (born between 1965-1980)
# 3               Millennial (born between 1981-2000)
# 4             Generation X (born between 1965-1980)
# ...                                             ...
# 17023          Baby Boomer (born between 1946-1964)
# 17024           Millennial (born between 1981-2000)
# 17025           Millennial (born between 1981-2000)
# 17026           Millennial (born between 1981-2000)
# 17027                          Prefer not to answer
#
#       Please select the gender in which you identify. - Response  \
# 0                                                   Male
# 1                                                    NaN
# 2                                                   Male
# 3                                             Non-Binary
# 4                                                 Female
# ...                                                  ...
# 17023                                               Male
# 17024                                             Female
# 17025                                             Female
# 17026                                             Female
# 17027                                               Male
#
#       Which duration range best aligns with your tenure at your company? - Response  \
# 0                                              0-2 years
# 1                                              10+ years
# 2                                              3-5 years
# 3                                             5-10 years
# 4                                              10+ years
# ...                                                  ...
# 17023                                          10+ years
# 17024                                         5-10 years
# 17025                                          3-5 years
# 17026                                          3-5 years
# 17027                                         5-10 years
#
#       Which of the following best describes your employment type? - Response  \
# 0                                     Full time Employee
# 1                                     Full time Employee
# 2                                     Full time Employee
# 3                                     Full time Employee
# 4                                     Full time Employee
# ...                                                  ...
# 17023                                 Full time Employee
# 17024                                 Full time Employee
# 17025                                 Full time Employee
# 17026                                 Full time Employee
# 17027                                 Full time Employee
#
#          Question + Subquestion    Answer    Question   Respondent ID - _y
# 0         Question 1 - Response       NaN   Question 1                 119
# 1         Question 1 - Response  Answer 4   Question 1                 119
# 2         Question 1 - Response  Answer 5   Question 1                 119
# 3         Question 1 - Response  Answer 1   Question 1                 119
# 4         Question 1 - Response       NaN   Question 1                 119
# ...                         ...       ...          ...                 ...
# 17023  Question 30 - Response 3  Answer 8  Question 30                 332
# 17024  Question 30 - Response 3  Answer 6  Question 30                 332
# 17025  Question 30 - Response 3       NaN  Question 30                 332
# 17026  Question 30 - Response 3       NaN  Question 30                 332
# 17027  Question 30 - Response 3       NaN  Question 30                 332
#
# [17028 rows x 12 columns]

# %%
same_answer = same_answer.groupby(["Question + Subquestion", "Answer"])["Respondent ID - "].count().reset_index()
same_answer.rename(columns={"Respondent ID - ": "Same Answer"}, inplace=True)
same_answer
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[147], line 1
# ----> 1 same_answer = same_answer.groupby(["Question + Subquestion", "Answer"])["Respondent ID - "].count().reset_index()
#       2 same_answer.rename(columns={"Respondent ID - ": "Same Answer"}, inplace=True)
#       3 same_answer
#
# NameError: name 'same_answer' is not defined

# %%
dataset_merged_three = pd.merge(left=dataset_merged_two, right=same_answer, how='left', left_on=['Question + Subquestion','Answer'], right_on=['Question + Subquestion','Answer'])
dataset_merged_three["Same Answer"].fillna(0, inplace=True)
print('Original Data:', len(dataset_merged_two))
print('Merged Data:', len(dataset_merged_three))
dataset_merged_three
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[87], line 1
# ----> 1 dataset_merged_three = pd.merge(left=dataset_merged_two, right=same_answer, how='left', left_on=['Question + Subquestion','Answer'], right_on=['Question + Subquestion','Answer'])
#       2 dataset_merged_three["Same Answer"].fillna(0, inplace=True)
#       3 print('Original Data:', len(dataset_merged_two))
#
# NameError: name 'same_answer' is not defined

# %%
output = dataset_merged_three.copy()
output.rename(columns={'Identify which division you work in. - Response':'Division Primary', 'Identify which division you work in. - Other (please specify)':'Division Secondary', 'Which of the following best describes your position level? - Response':'Position', 'Which generation are you apart of? - Response':'Generation', 'Please select the gender in which you identify. - Response':'Gender', 'Which duration range best aligns with your tenure at your company? - Response':'Tenure', 'Which of the following best describes your employment type? - Response':'Employment Type'}, inplace=True)
output
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[142], line 1
# ----> 1 output = dataset_merged_three.copy()
#       2 output.rename(columns={'Identify which division you work in. - Response':'Division Primary', 'Identify which division you work in. - Other (please specify)':'Division Secondary', 'Which of the following best describes your position level? - Response':'Position', 'Which generation are you apart of? - Response':'Generation', 'Please select the gender in which you identify. - Response':'Gender', 'Which duration range best aligns with your tenure at your company? - Response':'Tenure', 'Which of the following best describes your employment type? - Response':'Employment Type'}, inplace=True)
#       3 output
#
# NameError: name 'dataset_merged_three' is not defined
