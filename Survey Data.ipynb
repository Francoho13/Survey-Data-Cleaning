# %%
import pandas as pd
import os

# %%
pwd = os.getcwd()

# %%
dataset = pd.read_excel(pwd + "/Data Survey - edited.xlsx")
dataset
# Out:
#      Respondent ID          Start Date            End Date  Email Address  \
# 0              NaN                 NaT                 NaT            NaN
# 1     5.379192e+09 2021-01-22 12:01:17 2021-01-22 12:40:34            NaN
# 2     2.658723e+09 2021-01-22 06:56:37 2021-01-22 07:34:10            NaN
# 3     4.044163e+09 2021-01-22 06:35:18 2021-01-22 06:47:32            NaN
# 4     5.535866e+09 2021-01-21 21:29:32 2021-01-21 21:40:24            NaN
# ..             ...                 ...                 ...            ...
# 194   7.940065e+09 2021-01-11 06:19:18 2021-01-11 06:32:59            NaN
# 195   5.157706e+09 2021-01-11 06:19:14 2021-01-11 06:33:29            NaN
# 196   9.920756e+09 2021-01-11 06:18:48 2021-01-11 06:27:27            NaN
# 197   6.638341e+09 2021-01-11 06:19:01 2021-01-11 06:33:06            NaN
# 198   8.114622e+09 2021-01-11 06:18:50 2021-01-11 06:26:46            NaN
#
#      First Name  Last Name  Custom Data 1  \
# 0           NaN        NaN            NaN
# 1           NaN        NaN            NaN
# 2           NaN        NaN            NaN
# 3           NaN        NaN            NaN
# 4           NaN        NaN            NaN
# ..          ...        ...            ...
# 194         NaN        NaN            NaN
# 195         NaN        NaN            NaN
# 196         NaN        NaN            NaN
# 197         NaN        NaN            NaN
# 198         NaN        NaN            NaN
#
#     Identify which division you work in.              Unnamed: 8  \
# 0                               Response  Other (please specify)
# 1                         Infrastructure                     NaN
# 2                                Finance                     NaN
# 3                         Infrastructure                     NaN
# 4                         Infrastructure                     NaN
# ..                                   ...                     ...
# 194                       Infrastructure                     NaN
# 195                              Finance                     NaN
# 196                      Port Operations                     NaN
# 197                       Infrastructure                     NaN
# 198               Information Technology                     NaN
#
#     Which of the following best describes your position level?  ...  \
# 0                                             Response          ...
# 1                                                Staff          ...
# 2                                                Staff          ...
# 3                                      Department Lead          ...
# 4                                              Manager          ...
# ..                                                 ...          ...
# 194                                    Department Lead          ...
# 195                                              Staff          ...
# 196                                              Staff          ...
# 197                                            Manager          ...
# 198                                              Staff          ...
#
#     Unnamed: 90 Unnamed: 91  Unnamed: 92  Unnamed: 93  Unnamed: 94  \
# 0    Response 8  Response 9  Response 10  Response 11  Response 12
# 1           NaN    Answer 8     Answer 8     Answer 4          NaN
# 2           NaN    Answer 5          NaN          NaN     Answer 2
# 3           NaN         NaN     Answer 4     Answer 4     Answer 6
# 4      Answer 2    Answer 5     Answer 7          NaN     Answer 6
# ..          ...         ...          ...          ...          ...
# 194    Answer 1    Answer 1     Answer 3     Answer 6     Answer 6
# 195    Answer 5         NaN     Answer 5          NaN          NaN
# 196         NaN    Answer 7          NaN          NaN          NaN
# 197    Answer 2         NaN     Answer 3     Answer 5          NaN
# 198    Answer 3         NaN     Answer 7          NaN          NaN
#
#      Unnamed: 95  Unnamed: 96 Question 30 Unnamed: 98 Unnamed: 99
# 0    Response 13  Response 14  Response 1  Response 2  Response 3
# 1            NaN     Answer 5         NaN         NaN         NaN
# 2            NaN     Answer 5         NaN         NaN    Answer 1
# 3            NaN     Answer 6         NaN    Answer 1         NaN
# 4            NaN     Answer 7    Answer 7    Answer 1    Answer 6
# ..           ...          ...         ...         ...         ...
# 194     Answer 8          NaN         NaN         NaN    Answer 8
# 195     Answer 2          NaN         NaN         NaN    Answer 6
# 196          NaN          NaN         NaN    Answer 3         NaN
# 197     Answer 8     Answer 3    Answer 3         NaN         NaN
# 198          NaN          NaN    Answer 3         NaN         NaN
#
# [199 rows x 100 columns]

# %%
dataset_modified = dataset.copy()

# %%
columns_to_drop = ['Start Date - ','End Date - ','Email Address - ','First Name - ','Last Name - ', 'Custom Data 1 - ']
columns_to_drop
# Out:
# ['Start Date - ',
#  'End Date - ',
#  'Email Address - ',
#  'First Name - ',
#  'Last Name - ',
#  'Custom Data 1 - ']

# %%
id_vars = list(dataset_modified.columns)[:8]
value_vars = list(dataset_modified.columns)[8:]

# %%
dataset_melted = dataset_modified.melt(id_vars=id_vars, value_vars=value_vars, var_name="Question + Subquestion", value_name="Answer")
dataset_melted
# Out:
#        Respondent ID          Start Date            End Date  Email Address  \
# 0                NaN                 NaT                 NaT            NaN
# 1       5.379192e+09 2021-01-22 12:01:17 2021-01-22 12:40:34            NaN
# 2       2.658723e+09 2021-01-22 06:56:37 2021-01-22 07:34:10            NaN
# 3       4.044163e+09 2021-01-22 06:35:18 2021-01-22 06:47:32            NaN
# 4       5.535866e+09 2021-01-21 21:29:32 2021-01-21 21:40:24            NaN
# ...              ...                 ...                 ...            ...
# 18303   7.940065e+09 2021-01-11 06:19:18 2021-01-11 06:32:59            NaN
# 18304   5.157706e+09 2021-01-11 06:19:14 2021-01-11 06:33:29            NaN
# 18305   9.920756e+09 2021-01-11 06:18:48 2021-01-11 06:27:27            NaN
# 18306   6.638341e+09 2021-01-11 06:19:01 2021-01-11 06:33:06            NaN
# 18307   8.114622e+09 2021-01-11 06:18:50 2021-01-11 06:26:46            NaN
#
#        First Name  Last Name  Custom Data 1  \
# 0             NaN        NaN            NaN
# 1             NaN        NaN            NaN
# 2             NaN        NaN            NaN
# 3             NaN        NaN            NaN
# 4             NaN        NaN            NaN
# ...           ...        ...            ...
# 18303         NaN        NaN            NaN
# 18304         NaN        NaN            NaN
# 18305         NaN        NaN            NaN
# 18306         NaN        NaN            NaN
# 18307         NaN        NaN            NaN
#
#       Identify which division you work in. Question + Subquestion  \
# 0                                 Response             Unnamed: 8
# 1                           Infrastructure             Unnamed: 8
# 2                                  Finance             Unnamed: 8
# 3                           Infrastructure             Unnamed: 8
# 4                           Infrastructure             Unnamed: 8
# ...                                    ...                    ...
# 18303                       Infrastructure            Unnamed: 99
# 18304                              Finance            Unnamed: 99
# 18305                      Port Operations            Unnamed: 99
# 18306                       Infrastructure            Unnamed: 99
# 18307               Information Technology            Unnamed: 99
#
#                        Answer
# 0      Other (please specify)
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ...                       ...
# 18303                Answer 8
# 18304                Answer 6
# 18305                     NaN
# 18306                     NaN
# 18307                     NaN
#
# [18308 rows x 10 columns]

# %%
questions_import = pd.read_excel(pwd + "/Data Survey - edited.xlsx", sheet_name="Questions")
questions_import
# Out:
#          Question Raw Subquestion      Question   Subquestion  \
# 0   Respondent ID             NaN  Respondent ID          NaN
# 1      Start Date             NaN     Start Date          NaN
# 2        End Date             NaN       End Date          NaN
# 3   Email Address             NaN  Email Address          NaN
# 4      First Name             NaN     First Name          NaN
# ..            ...             ...            ...          ...
# 95            NaN     Response 13    Question 29  Response 13
# 96            NaN     Response 14    Question 29  Response 14
# 97    Question 30      Response 1    Question 30   Response 1
# 98            NaN      Response 2    Question 30   Response 2
# 99            NaN      Response 3    Question 30   Response 3
#
#       Question + Subquestions
# 0            Respondent ID -
# 1               Start Date -
# 2                 End Date -
# 3            Email Address -
# 4               First Name -
# ..                        ...
# 95  Question 29 - Response 13
# 96  Question 29 - Response 14
# 97   Question 30 - Response 1
# 98   Question 30 - Response 2
# 99   Question 30 - Response 3
#
# [100 rows x 5 columns]

# %%
questions = questions_import.copy()
questions.drop(columns=["Question", "Raw Subquestion", "Subquestion"], inplace=True)
questions.rename(columns={'Question + Subquestions': 'Question + Subquestion'}, inplace=True)
questions
# Out:
#         Question      Question + Subquestion
# 0   Respondent ID           Respondent ID -
# 1      Start Date              Start Date -
# 2        End Date                End Date -
# 3   Email Address           Email Address -
# 4      First Name              First Name -
# ..            ...                        ...
# 95    Question 29  Question 29 - Response 13
# 96    Question 29  Question 29 - Response 14
# 97    Question 30   Question 30 - Response 1
# 98    Question 30   Question 30 - Response 2
# 99    Question 30   Question 30 - Response 3
#
# [100 rows x 2 columns]

# %%
dataset_merged = pd.merge(left=dataset_melted, right=questions, how='left', on='Question + Subquestion')
dataset_merged
# Out:
#        Respondent ID          Start Date            End Date  Email Address  \
# 0                NaN                 NaT                 NaT            NaN
# 1       5.379192e+09 2021-01-22 12:01:17 2021-01-22 12:40:34            NaN
# 2       2.658723e+09 2021-01-22 06:56:37 2021-01-22 07:34:10            NaN
# 3       4.044163e+09 2021-01-22 06:35:18 2021-01-22 06:47:32            NaN
# 4       5.535866e+09 2021-01-21 21:29:32 2021-01-21 21:40:24            NaN
# ...              ...                 ...                 ...            ...
# 18303   7.940065e+09 2021-01-11 06:19:18 2021-01-11 06:32:59            NaN
# 18304   5.157706e+09 2021-01-11 06:19:14 2021-01-11 06:33:29            NaN
# 18305   9.920756e+09 2021-01-11 06:18:48 2021-01-11 06:27:27            NaN
# 18306   6.638341e+09 2021-01-11 06:19:01 2021-01-11 06:33:06            NaN
# 18307   8.114622e+09 2021-01-11 06:18:50 2021-01-11 06:26:46            NaN
#
#        First Name  Last Name  Custom Data 1  \
# 0             NaN        NaN            NaN
# 1             NaN        NaN            NaN
# 2             NaN        NaN            NaN
# 3             NaN        NaN            NaN
# 4             NaN        NaN            NaN
# ...           ...        ...            ...
# 18303         NaN        NaN            NaN
# 18304         NaN        NaN            NaN
# 18305         NaN        NaN            NaN
# 18306         NaN        NaN            NaN
# 18307         NaN        NaN            NaN
#
#       Identify which division you work in. Question + Subquestion  \
# 0                                 Response             Unnamed: 8
# 1                           Infrastructure             Unnamed: 8
# 2                                  Finance             Unnamed: 8
# 3                           Infrastructure             Unnamed: 8
# 4                           Infrastructure             Unnamed: 8
# ...                                    ...                    ...
# 18303                       Infrastructure            Unnamed: 99
# 18304                              Finance            Unnamed: 99
# 18305                      Port Operations            Unnamed: 99
# 18306                       Infrastructure            Unnamed: 99
# 18307               Information Technology            Unnamed: 99
#
#                        Answer Question
# 0      Other (please specify)       NaN
# 1                         NaN       NaN
# 2                         NaN       NaN
# 3                         NaN       NaN
# 4                         NaN       NaN
# ...                       ...       ...
# 18303                Answer 8       NaN
# 18304                Answer 6       NaN
# 18305                     NaN       NaN
# 18306                     NaN       NaN
# 18307                     NaN       NaN
#
# [18308 rows x 11 columns]

# %%
dataset_merged.columns
# Out:
# Index(['Respondent ID', 'Start Date', 'End Date', 'Email Address',
#        'First Name', 'Last Name', 'Custom Data 1',
#        'Identify which division you work in.', 'Question + Subquestion',
#        'Answer', 'Question '],
#       dtype='object')

# %%
respondents = dataset_merged[dataset_merged["Answer"].notna()]
respondents = respondents.groupby("Question ")["Respondent ID"].count().reset_index()
respondents.rename(columns={"Respondent ID - ": "Respondents"}, inplace=True)

# %%
dataset_merged_two = pd.merge(left=dataset_merged, right=respondents, how='left', left_on='Question ', right_on='Question ')
dataset_merged_two
# Out:
#        Respondent ID_x          Start Date            End Date  Email Address  \
# 0                  NaN                 NaT                 NaT            NaN
# 1         5.379192e+09 2021-01-22 12:01:17 2021-01-22 12:40:34            NaN
# 2         2.658723e+09 2021-01-22 06:56:37 2021-01-22 07:34:10            NaN
# 3         4.044163e+09 2021-01-22 06:35:18 2021-01-22 06:47:32            NaN
# 4         5.535866e+09 2021-01-21 21:29:32 2021-01-21 21:40:24            NaN
# ...                ...                 ...                 ...            ...
# 18303     7.940065e+09 2021-01-11 06:19:18 2021-01-11 06:32:59            NaN
# 18304     5.157706e+09 2021-01-11 06:19:14 2021-01-11 06:33:29            NaN
# 18305     9.920756e+09 2021-01-11 06:18:48 2021-01-11 06:27:27            NaN
# 18306     6.638341e+09 2021-01-11 06:19:01 2021-01-11 06:33:06            NaN
# 18307     8.114622e+09 2021-01-11 06:18:50 2021-01-11 06:26:46            NaN
#
#        First Name  Last Name  Custom Data 1  \
# 0             NaN        NaN            NaN
# 1             NaN        NaN            NaN
# 2             NaN        NaN            NaN
# 3             NaN        NaN            NaN
# 4             NaN        NaN            NaN
# ...           ...        ...            ...
# 18303         NaN        NaN            NaN
# 18304         NaN        NaN            NaN
# 18305         NaN        NaN            NaN
# 18306         NaN        NaN            NaN
# 18307         NaN        NaN            NaN
#
#       Identify which division you work in. Question + Subquestion  \
# 0                                 Response             Unnamed: 8
# 1                           Infrastructure             Unnamed: 8
# 2                                  Finance             Unnamed: 8
# 3                           Infrastructure             Unnamed: 8
# 4                           Infrastructure             Unnamed: 8
# ...                                    ...                    ...
# 18303                       Infrastructure            Unnamed: 99
# 18304                              Finance            Unnamed: 99
# 18305                      Port Operations            Unnamed: 99
# 18306                       Infrastructure            Unnamed: 99
# 18307               Information Technology            Unnamed: 99
#
#                        Answer Question   Respondent ID_y
# 0      Other (please specify)       NaN              NaN
# 1                         NaN       NaN              NaN
# 2                         NaN       NaN              NaN
# 3                         NaN       NaN              NaN
# 4                         NaN       NaN              NaN
# ...                       ...       ...              ...
# 18303                Answer 8       NaN              NaN
# 18304                Answer 6       NaN              NaN
# 18305                     NaN       NaN              NaN
# 18306                     NaN       NaN              NaN
# 18307                     NaN       NaN              NaN
#
# [18308 rows x 12 columns]

# %%
print(dataset_merged_two.columns.tolist())
# Out:
# ['Respondent ID_x', 'Start Date', 'End Date', 'Email Address', 'First Name', 'Last Name', 'Custom Data 1', 'Identify which division you work in.', 'Question + Subquestion', 'Answer', 'Question ', 'Respondent ID_y']

# %%
same_answer = dataset_merged_two.groupby(["Question + Subquestion", "Answer"])["Respondent ID_x"].count().reset_index()
same_answer.rename(columns={"Respondent ID_x": "Same Answer"}, inplace=True)
same_answer
# Out:
#                                 Question + Subquestion                Answer  \
# 0      Please select the gender in which you identify.                Female
# 1      Please select the gender in which you identify.                  Male
# 2      Please select the gender in which you identify.            Non-Binary
# 3      Please select the gender in which you identify.  Prefer not to answer
# 4      Please select the gender in which you identify.              Response
# ..                                                 ...                   ...
# 795  Which of the following best describes your pos...     Chief / Executive
# 796  Which of the following best describes your pos...       Department Lead
# 797  Which of the following best describes your pos...               Manager
# 798  Which of the following best describes your pos...              Response
# 799  Which of the following best describes your pos...                 Staff
#
#      Same Answer
# 0             96
# 1             86
# 2              1
# 3             13
# 4              0
# ..           ...
# 795            6
# 796           28
# 797           46
# 798            0
# 799          116
#
# [800 rows x 3 columns]

# %%
dataset_merged_three = pd.merge(left=dataset_merged_two, right=same_answer, how='left', left_on=['Question + Subquestion', 'Answer'], right_on=['Question + Subquestion', 'Answer'])
dataset_merged_three["Same Answer"].fillna(0, inplace=True)
# Out:
# C:\Users\franc\AppData\Local\Temp\ipykernel_40920\2083193230.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset_merged_three["Same Answer"].fillna(0, inplace=True)

# %%
output = dataset_merged_three.copy()
output.rename(columns={
    'Identify which division you work in. - Response': 'Division Primary',
    'Identify which division you work in. - Other (please specify)': 'Division Secondary',
    'Which of the following best describes your position level? - Response': 'Position',
    'Which generation are you apart of? - Response': 'Generation',
    'Please select the gender in which you identify. - Response': 'Gender',
    'Which duration range best aligns with your tenure at your company? - Response': 'Tenure',
    'Which of the following best describes your employment type? - Response': 'Employment Type'
}, inplace=True)
